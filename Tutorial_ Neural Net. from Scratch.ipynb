# %% [markdown]
# # **#Tutorial: Neural Net. from Scratch**

# %% [markdown]
# ![image.png](attachment:image.png)
# <div style="text-align: right">  -Google Image </div>

# %%
#Features: X1, X2 Label:Y
X1=[1.0,2.0,3.0,4.0] #Input 1
X2=[3.0,6.0,9.0,12.0] #Input 2
Y=[5.0,10.0,15.0,20.0] #Derived from 2*(x1) + 1*(x2) [2-Dimentional]
#Initilizing Parameters
w1,w2,b=0,0,0 #We want the Nural Net. to figure this out, so it is assigned as 0.
alpha=0.01 #Learning Rate
iteration=1
x=0
costDV=1
while costDV!=0: 
        print("Iteration:",iteration)
        iteration+=1
        #Forward Propagation
        pred=(w1*X1[x%4])+(w2*X2[x%4]) #Hidden Layer
        #Back Propogation: Using Chain rule on Cost
        costDV=(pred-Y[x%4]) #It is actually 2*(pred-y1[x%4]), but it is optimized
        costDV_w1=costDV*(X1[x%4]) #Partial Derivative of w1
        costDV_w2=costDV*(X2[x%4]) #Partial Derivative of w2
        b=Y[x%4]-pred
        print("Prediction",round(pred,3),"Actual",Y[x%4],"Cost Derivative:","//",round(costDV,3),"//",round(costDV_w1,3),round(costDV_w2,2),round(b,2))
        print("w1:",w1,"\nw2:",w2,"\nbias:",round(b,3),"\n") #This is derived from 3-D plain.
        #Gradient Descent: Changing the weight besed on Derivative until it becomes 0.
        w1-=alpha*(costDV_w1)
        w2-=alpha*(costDV_w2)
        x+=1
# Out:
# Iteration: 1
# Prediction 0.0 Actual 5.0 Cost Derivative: // -5.0 // -5.0 -15.0 5.0
# w1: 0
# w2: 0
# bias: 5.0
#
# Iteration: 2
# Prediction 1.0 Actual 10.0 Cost Derivative: // -9.0 // -18.0 -54.0 9.0
# w1: 0.05
# w2: 0.15
# bias: 9.0
#
# Iteration: 3
# Prediction 6.9 Actual 15.0 Cost Derivative: // -8.1 // -24.3 -72.9 8.1
# w1: 0.22999999999999998
# w2: 0.6900000000000001
# bias: 8.1
#
# Iteration: 4
# Prediction 18.92 Actual 20.0 Cost Derivative: // -1.08 // -4.32 -12.96 1.08
# w1: 0.473
# w2: 1.419
# bias: 1.08
#
# Iteration: 5
# Prediction 5.162 Actual 5.0 Cost Derivative: // 0.162 // 0.162 0.49 -0.16
# w1: 0.5162
# w2: 1.5486000000000002
# bias: -0.162
#
# Iteration: 6
# Prediction 10.292 Actual 10.0 Cost Derivative: // 0.292 // 0.583 1.75 -0.29
# w1: 0.51458
# w2: 1.5437400000000001
# bias: -0.292
#
# Iteration: 7
# Prediction 15.262 Actual 15.0 Cost Derivative: // 0.262 // 0.787 2.36 -0.26
# w1: 0.508748
# w2: 1.526244
# bias: -0.262
#
# Iteration: 8
# Prediction 20.035 Actual 20.0 Cost Derivative: // 0.035 // 0.14 0.42 -0.03
# w1: 0.5008748
# w2: 1.5026244
# bias: -0.035
#
# Iteration: 9
# Prediction 4.995 Actual 5.0 Cost Derivative: // -0.005 // -0.005 -0.02 0.01
# w1: 0.49947512
# w2: 1.4984253600000002
# bias: 0.005
#
# Iteration: 10
# Prediction 9.991 Actual 10.0 Cost Derivative: // -0.009 // -0.019 -0.06 0.01
# w1: 0.499527608
# w2: 1.498582824
# bias: 0.009
#
# Iteration: 11
# Prediction 14.991 Actual 15.0 Cost Derivative: // -0.009 // -0.026 -0.08 0.01
# w1: 0.4997165648
# w2: 1.4991496944
# bias: 0.009
#
# Iteration: 12
# Prediction 19.999 Actual 20.0 Cost Derivative: // -0.001 // -0.005 -0.01 0.0
# w1: 0.49997165647999997
# w2: 1.49991496944
# bias: 0.001
#
# Iteration: 13
# Prediction 5.0 Actual 5.0 Cost Derivative: // 0.0 // 0.0 0.0 -0.0
# w1: 0.500017006112
# w2: 1.500051018336
# bias: -0.0
#
# Iteration: 14
# Prediction 10.0 Actual 10.0 Cost Derivative: // 0.0 // 0.001 0.0 -0.0
# w1: 0.5000153055008
# w2: 1.5000459165024
# bias: -0.0
#
# Iteration: 15
# Prediction 15.0 Actual 15.0 Cost Derivative: // 0.0 // 0.001 0.0 -0.0
# w1: 0.5000091833004799
# w2: 1.50002754990144
# bias: -0.0
#
# Iteration: 16
# Prediction 20.0 Actual 20.0 Cost Derivative: // 0.0 // 0.0 0.0 -0.0
# w1: 0.500000918330048
# w2: 1.500002754990144
# bias: -0.0
#
# Iteration: 17
# Prediction 5.0 Actual 5.0 Cost Derivative: // -0.0 // -0.0 -0.0 0.0
# w1: 0.4999994490019711
# w2: 1.499998347005913
# bias: 0.0
#
# Iteration: 18
# Prediction 10.0 Actual 10.0 Cost Derivative: // -0.0 // -0.0 -0.0 0.0
# w1: 0.49999950410177396
# w2: 1.4999985123053217
# bias: 0.0
#
# Iteration: 19
# Prediction 15.0 Actual 15.0 Cost Derivative: // -0.0 // -0.0 -0.0 0.0
# w1: 0.4999997024610644
# w2: 1.499999107383193
# bias: 0.0
#
# Iteration: 20
# Prediction 20.0 Actual 20.0 Cost Derivative: // -0.0 // -0.0 -0.0 0.0
# w1: 0.4999999702461065
# w2: 1.4999999107383193
# bias: 0.0
#
# Iteration: 21
# Prediction 5.0 Actual 5.0 Cost Derivative: // 0.0 // 0.0 0.0 -0.0
# w1: 0.5000000178523362
# w2: 1.5000000535570084
# bias: -0.0
#
# Iteration: 22
# Prediction 10.0 Actual 10.0 Cost Derivative: // 0.0 // 0.0 0.0 -0.0
# w1: 0.5000000160671025
# w2: 1.5000000482013076
# bias: -0.0
#
# Iteration: 23
# Prediction 15.0 Actual 15.0 Cost Derivative: // 0.0 // 0.0 0.0 -0.0
# w1: 0.5000000096402616
# w2: 1.5000000289207847
# bias: -0.0
#
# Iteration: 24
# Prediction 20.0 Actual 20.0 Cost Derivative: // 0.0 // 0.0 0.0 -0.0
# w1: 0.5000000009640262
# w2: 1.5000000028920784
# bias: -0.0
#
# Iteration: 25
# Prediction 5.0 Actual 5.0 Cost Derivative: // -0.0 // -0.0 -0.0 0.0
# w1: 0.4999999994215844
# w2: 1.4999999982647532
# bias: 0.0
#
# Iteration: 26
# Prediction 10.0 Actual 10.0 Cost Derivative: // -0.0 // -0.0 -0.0 0.0
# w1: 0.49999999947942597
# w2: 1.499999998438278
# bias: 0.0
#
# Iteration: 27
# Prediction 15.0 Actual 15.0 Cost Derivative: // -0.0 // -0.0 -0.0 0.0
# w1: 0.49999999968765557
# w2: 1.4999999990629667
# bias: 0.0
#
# Iteration: 28
# Prediction 20.0 Actual 20.0 Cost Derivative: // -0.0 // -0.0 -0.0 0.0
# w1: 0.4999999999687656
# w2: 1.4999999999062967
# bias: 0.0
#
# Iteration: 29
# Prediction 5.0 Actual 5.0 Cost Derivative: // 0.0 // 0.0 0.0 -0.0
# w1: 0.5000000000187408
# w2: 1.5000000000562221
# bias: -0.0
#
# Iteration: 30
# Prediction 10.0 Actual 10.0 Cost Derivative: // 0.0 // 0.0 0.0 -0.0
# w1: 0.5000000000168667
# w2: 1.5000000000506
# bias: -0.0
#
# Iteration: 31
# Prediction 15.0 Actual 15.0 Cost Derivative: // 0.0 // 0.0 0.0 -0.0
# w1: 0.50000000001012
# w2: 1.50000000003036
# bias: -0.0
#
# Iteration: 32
# Prediction 20.0 Actual 20.0 Cost Derivative: // 0.0 // 0.0 0.0 -0.0
# w1: 0.5000000000010121
# w2: 1.500000000003036
# bias: -0.0
#
# Iteration: 33
# Prediction 5.0 Actual 5.0 Cost Derivative: // -0.0 // -0.0 -0.0 0.0
# w1: 0.4999999999993929
# w2: 1.4999999999981786
# bias: 0.0
#
# Iteration: 34
# Prediction 10.0 Actual 10.0 Cost Derivative: // -0.0 // -0.0 -0.0 0.0
# w1: 0.4999999999994536
# w2: 1.4999999999983606
# bias: 0.0
#
# Iteration: 35
# Prediction 15.0 Actual 15.0 Cost Derivative: // -0.0 // -0.0 -0.0 0.0
# w1: 0.49999999999967215
# w2: 1.4999999999990163
# bias: 0.0
#
# Iteration: 36
# Prediction 20.0 Actual 20.0 Cost Derivative: // -0.0 // -0.0 -0.0 0.0
# w1: 0.49999999999996725
# w2: 1.4999999999999016
# bias: 0.0
#
# Iteration: 37
# Prediction 5.0 Actual 5.0 Cost Derivative: // 0.0 // 0.0 0.0 -0.0
# w1: 0.5000000000000197
# w2: 1.5000000000000588
# bias: -0.0
#
# Iteration: 38
# Prediction 10.0 Actual 10.0 Cost Derivative: // 0.0 // 0.0 0.0 -0.0
# w1: 0.5000000000000177
# w2: 1.5000000000000528
# bias: -0.0
#
# Iteration: 39
# Prediction 15.0 Actual 15.0 Cost Derivative: // 0.0 // 0.0 0.0 -0.0
# w1: 0.5000000000000107
# w2: 1.5000000000000318
# bias: -0.0
#
# Iteration: 40
# Prediction 20.0 Actual 20.0 Cost Derivative: // 0.0 // 0.0 0.0 -0.0
# w1: 0.5000000000000011
# w2: 1.500000000000003
# bias: -0.0
#
# Iteration: 41
# Prediction 5.0 Actual 5.0 Cost Derivative: // -0.0 // -0.0 -0.0 0.0
# w1: 0.49999999999999956
# w2: 1.4999999999999984
# bias: 0.0
#
# Iteration: 42
# Prediction 10.0 Actual 10.0 Cost Derivative: // -0.0 // -0.0 -0.0 0.0
# w1: 0.4999999999999996
# w2: 1.4999999999999987
# bias: 0.0
#
# Iteration: 43
# Prediction 15.0 Actual 15.0 Cost Derivative: // -0.0 // -0.0 -0.0 0.0
# w1: 0.4999999999999998
# w2: 1.4999999999999991
# bias: 0.0
#
# Iteration: 44
# Prediction 20.0 Actual 20.0 Cost Derivative: // -0.0 // -0.0 -0.0 0.0
# w1: 0.5
# w2: 1.4999999999999998
# bias: 0.0
#
# Iteration: 45
# Prediction 5.0 Actual 5.0 Cost Derivative: // 0.0 // 0.0 0.0 -0.0
# w1: 0.5000000000000001
# w2: 1.5000000000000002
# bias: -0.0
#
# Iteration: 46
# Prediction 10.0 Actual 10.0 Cost Derivative: // 0.0 // 0.0 0.0 -0.0
# w1: 0.5000000000000001
# w2: 1.5000000000000002
# bias: -0.0
#
# Iteration: 47
# Prediction 15.0 Actual 15.0 Cost Derivative: // 0.0 // 0.0 0.0 -0.0
# w1: 0.5000000000000001
# w2: 1.5000000000000002
# bias: -0.0
#
# Iteration: 48
# Prediction 20.0 Actual 20.0 Cost Derivative: // 0.0 // 0.0 0.0 0.0
# w1: 0.5000000000000001
# w2: 1.5
# bias: 0.0

# %% [markdown]
# # #Cross-Validation using Sklearn Library

# %%
#Initilizing the data into a Pandas Dataframe using Numpy
import pandas as pd
import numpy as np
x1=[1.0,2.0,3.0,4.0]
x2=[3.0,6.0,9.0,12.0]
y1=[5.0,10.0,15.0,20.0]
df=pd.DataFrame(x1,columns=["x1"])
df["x2"]=np.array(x2)
df["y1"]=y1
df.describe()
# Out:
#              x1         x2         y1
# count  4.000000   4.000000   4.000000
# mean   2.500000   7.500000  12.500000
# std    1.290994   3.872983   6.454972
# min    1.000000   3.000000   5.000000
# 25%    1.750000   5.250000   8.750000
# 50%    2.500000   7.500000  12.500000
# 75%    3.250000   9.750000  16.250000
# max    4.000000  12.000000  20.000000

# %%
from sklearn import linear_model
model=linear_model.LinearRegression()
model.fit(df[["x1","x2"]],df["y1"])
print("Coefficients (w1 and w2) from SKlearn Library:",model.coef_)
print("Coefficients (w1 and w2) from Nural Net from Scratch:",round(w1,2),round(w2,2))
# Out:
# Coefficients (w1 and w2) from SKlearn Library: [0.5 1.5]
# Coefficients (w1 and w2) from Nural Net from Scratch: 0.5 1.5
